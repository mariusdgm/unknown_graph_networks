# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, sys


def get_dir_n_levels_up(path, n):
    # Go up n levels from the given path
    for _ in range(n):
        path = os.path.dirname(path)
    return path

proj_root = get_dir_n_levels_up(os.path.abspath("__file__"), 3)
sys.path.append(proj_root)

# %%
# import time
# from opinion_dynamics.experiments.online import run_multi_seed_experiment_dynamics

# def timed_one(seed, dynamics):
#     t0 = time.time()
#     if dynamics == "laplacian":
#         df = run_multi_seed_experiment_dynamics(
#             seeds=[seed],
#             dynamics_model=dynamics,
#             B_campaign=1.0,
#             num_campaigns_total=5,
#             suppress_fit_logs=True,
#         )
#     elif dynamics == "coca":
#         df = run_multi_seed_experiment_dynamics(
#             seeds=[seed],
#             dynamics_model=dynamics,
#             B_campaign=1.0,
#             num_campaigns_total=5,
#             suppress_fit_logs=True,
#             fit_max_steps=10000,
#             fit_mae_stop=2e-3,
#             fit_batch_size=256,
#         )
#     dt = time.time() - t0

#     row = df.iloc[0].to_dict()
#     print(f"[{dynamics}] seed={seed} total_time={dt:.2f}s")

#     # Only print if those columns exist
#     if "time_online" in row:
#         print(
#             f"  time_online={row.get('time_online', float('nan')):.3f}s | "
#             f"time_fit_inner={row.get('time_fit_inner', float('nan')):.3f}s | "
#             f"time_step_inner={row.get('time_step_inner', float('nan')):.3f}s | "
#             f"fit_calls={row.get('fit_calls_inner', 'NA')} | "
#             f"step_calls={row.get('step_calls_inner', 'NA')}"
#         )

#     return df

# timed_one(0, "laplacian")
# timed_one(0, "coca")

# %%
# =========================================================
# Multi-seed experiment across ALL propagation methods
# (10 seeds, repeated per topology)
# Report only the FINAL repeat per seed so results are comparable
# to the older one-point-per-seed experiments.
# =========================================================

import matplotlib.pyplot as plt
import pandas as pd

from opinion_dynamics.experiments.online_repeated import (
    run_multi_seed_repeated_experiment_dynamics,
)

seeds = range(10)
B_campaign = 1.0
num_campaigns_total = 5
FIT_MAX_STEPS = 5_000
NUM_REPEATS = 100

DYNAMICS_LIST = [
    "laplacian",
    "coca",
    "friedkinjohnsen",
    "hegselmannkrause",
    "nonlinearinfluence",
    # "repulsion",
]

FIT_BY_DYNAMICS = {
    "laplacian": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=1e-2, fit_batch_size=256, fit_check_every=200),
    "coca": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=512, fit_check_every=200),
    "friedkinjohnsen": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    "hegselmannkrause": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    "nonlinearinfluence": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    # "repulsion": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=3e-2, fit_batch_size=256, fit_check_every=200),
}

dfs_final = []
dfs_all = {}

for dyn in DYNAMICS_LIST:
    print(f"=== Running {dyn} ===")
    df_all = run_multi_seed_repeated_experiment_dynamics(
        seeds=seeds,
        repeats_per_seed=NUM_REPEATS,
        dynamics_model=dyn,
        B_campaign=B_campaign,
        num_campaigns_total=num_campaigns_total,
        suppress_fit_logs=True,
        **FIT_BY_DYNAMICS[dyn],
    )
    dfs_all[dyn] = df_all

    df_final = (
        df_all.sort_values(["seed", "repeat"])
        .groupby("seed", as_index=False, group_keys=False)
        .tail(1)
        .reset_index(drop=True)
    )
    dfs_final.append(df_final)

df = pd.concat(dfs_final, axis=0).reset_index(drop=True)
display(df)

print("=== Aggregate by dynamics (final repeat only) ===")
cols = [
    "repeat",
    "train_pairs_total",
    "v_L1_final",
    "A_MAE_final",
    "mean_gap_to_oracle_end",
    "vx_gap_to_oracle_end",
    "time_fit_inner",
]
display(df.groupby("dynamics")[cols].describe().T)

for metric, ylabel, title in [
    ("A_MAE_final", "MAE(A_hat, A_true)", "Adjacency MAE vs seed (final accumulated repeat)"),
    ("v_L1_final", "||v_hat - v_true||_1", "Centrality error vs seed (final accumulated repeat)"),
    ("mean_gap_to_oracle_end", "oracle gap", "Mean gap to oracle vs seed (final accumulated repeat)"),
]:
    plt.figure(figsize=(10, 4))
    for dyn in DYNAMICS_LIST:
        sub = df[df["dynamics"] == dyn].sort_values("seed")
        plt.plot(sub["seed"], sub[metric], marker="o", label=dyn)
    plt.xlabel("seed")
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True, alpha=0.3)
    plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
    plt.show()
# Out:
# === Running laplacian ===
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === Running coca ===
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === Running friedkinjohnsen ===
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === Running hegselmannkrause ===
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === Running nonlinearinfluence ===
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
#     seed  repeat  repeat_seed            dynamics   N  train_pairs_total  \
# 0      0      99      1000000           laplacian  15               2000
# 1      1      99      1000001           laplacian  15               2000
# 2      2      99      1000002           laplacian  15               2000
# 3      3      99      1000003           laplacian  15               2000
# 4      4      99      1000004           laplacian  15               2000
# 5      5      99      1000005           laplacian  15               2000
# 6      6      99      1000006           laplacian  15               2000
# 7      7      99      1000007           laplacian  15               2000
# 8      8      99      1000008           laplacian  15               2000
# 9      9      99      1000009           laplacian  15               2000
# 10     0      99      1000000                coca  15               2000
# 11     1      99      1000001                coca  15               2000
# 12     2      99      1000002                coca  15               2000
# 13     3      99      1000003                coca  15               2000
# 14     4      99      1000004                coca  15               2000
# 15     5      99      1000005                coca  15               2000
# 16     6      99      1000006                coca  15               2000
# 17     7      99      1000007                coca  15               2000
# 18     8      99      1000008                coca  15               2000
# 19     9      99      1000009                coca  15               2000
# 20     0      99      1000000     friedkinjohnsen  15               2000
# 21     1      99      1000001     friedkinjohnsen  15               2000
# 22     2      99      1000002     friedkinjohnsen  15               2000
# 23     3      99      1000003     friedkinjohnsen  15               2000
# 24     4      99      1000004     friedkinjohnsen  15               2000
# 25     5      99      1000005     friedkinjohnsen  15               2000
# 26     6      99      1000006     friedkinjohnsen  15               2000
# 27     7      99      1000007     friedkinjohnsen  15               2000
# 28     8      99      1000008     friedkinjohnsen  15               2000
# 29     9      99      1000009     friedkinjohnsen  15               2000
# 30     0      99      1000000    hegselmannkrause  15               2000
# 31     1      99      1000001    hegselmannkrause  15               2000
# 32     2      99      1000002    hegselmannkrause  15               2000
# 33     3      99      1000003    hegselmannkrause  15               2000
# 34     4      99      1000004    hegselmannkrause  15               2000
# 35     5      99      1000005    hegselmannkrause  15               2000
# 36     6      99      1000006    hegselmannkrause  15               2000
# 37     7      99      1000007    hegselmannkrause  15               2000
# 38     8      99      1000008    hegselmannkrause  15               2000
# 39     9      99      1000009    hegselmannkrause  15               2000
# 40     0      99      1000000  nonlinearinfluence  15               2000
# 41     1      99      1000001  nonlinearinfluence  15               2000
# 42     2      99      1000002  nonlinearinfluence  15               2000
# 43     3      99      1000003  nonlinearinfluence  15               2000
# 44     4      99      1000004  nonlinearinfluence  15               2000
# 45     5      99      1000005  nonlinearinfluence  15               2000
# 46     6      99      1000006  nonlinearinfluence  15               2000
# 47     7      99      1000007  nonlinearinfluence  15               2000
# 48     8      99      1000008  nonlinearinfluence  15               2000
# 49     9      99      1000009  nonlinearinfluence  15               2000
#
#     v_L1_final  A_Fro_final  A_MAE_final  mean_oracle_end  ...  \
# 0     0.352870     1.747036     0.068722         0.704465  ...
# 1     0.313901     1.352136     0.058110         0.663044  ...
# 2     0.415216     1.153312     0.044454         0.698771  ...
# 3     0.440121     1.335164     0.053151         0.756526  ...
# 4     0.434956     1.080179     0.040896         0.803763  ...
# 5     0.366369     1.339402     0.049186         0.723045  ...
# 6     0.543323     1.437141     0.055314         0.748328  ...
# 7     0.588677     1.851431     0.069693         0.635498  ...
# 8     0.448458     1.014268     0.040196         0.750852  ...
# 9     0.259944     0.954743     0.037407         0.708920  ...
# 10    0.496331     2.143910     0.090058         0.666709  ...
# 11    0.493240     1.953660     0.081560         0.679159  ...
# 12    0.469890     2.163471     0.091869         0.688591  ...
# 13    0.441787     2.010125     0.082981         0.760642  ...
# 14    0.700979     2.523121     0.088742         0.789642  ...
# 15    0.443356     1.983058     0.053999         0.716321  ...
# 16    0.713383     1.944737     0.062546         0.789540  ...
# 17    0.494416     2.076652     0.083083         0.636982  ...
# 18    0.369051     1.825311     0.071027         0.755115  ...
# 19    0.423173     2.134382     0.087397         0.703862  ...
# 20    0.111045     0.270433     0.007436         0.585670  ...
# 21    0.132734     0.255476     0.007285         0.552789  ...
# 22    0.118787     0.255323     0.007016         0.577813  ...
# 23    0.123370     0.246216     0.006384         0.657587  ...
# 24    0.209472     0.232478     0.005467         0.711135  ...
# 25    0.105300     0.234777     0.005779         0.615714  ...
# 26    0.147306     0.282613     0.007469         0.637440  ...
# 27    0.108804     0.256828     0.005682         0.512551  ...
# 28    0.079785     0.252466     0.005692         0.661420  ...
# 29    0.088411     0.215604     0.005281         0.602890  ...
# 30    0.559270     2.570654     0.101291         0.623764  ...
# 31    0.505769     2.364333     0.101316         0.686881  ...
# 32    0.426566     2.473699     0.091673         0.675322  ...
# 33    0.386392     2.253046     0.094135         0.707639  ...
# 34    0.786773     3.236392     0.109047         0.753863  ...
# 35    0.535649     2.795343     0.090579         0.683801  ...
# 36    0.726255     3.009554     0.099153         0.677034  ...
# 37    0.938130     3.058932     0.100777         0.658064  ...
# 38    0.557887     3.048612     0.112079         0.763313  ...
# 39    0.521796     2.421958     0.098805         0.706469  ...
# 40    0.408356     0.870341     0.030887         0.703077  ...
# 41    0.422165     1.713118     0.073880         0.664715  ...
# 42    0.377327     1.295272     0.047891         0.697601  ...
# 43    0.316686     1.232037     0.049744         0.755625  ...
# 44    0.308521     0.968136     0.032639         0.805058  ...
# 45    0.397934     1.179777     0.041023         0.721980  ...
# 46    0.484735     1.447049     0.049220         0.752762  ...
# 47    0.282732     0.589477     0.020037         0.633373  ...
# 48    0.497134     2.069408     0.071245         0.748132  ...
# 49    0.203741     1.503055     0.053349         0.706670  ...
#
#     mean_gap_to_oracle_end  mean_err_avg  mean_err_max  vx_gap_to_oracle_end  \
# 0             4.738113e-04  7.896855e-05  4.738113e-04          9.105728e-05
# 1             8.293226e-03  3.162754e-03  8.293226e-03          8.652390e-03
# 2             6.674206e-03  3.533873e-03  6.674206e-03          8.156575e-03
# 3             1.401912e-02  6.589933e-03  1.401912e-02          1.271425e-02
# 4             2.096267e-02  9.090515e-03  2.096267e-02          2.461438e-02
# 5             2.653932e-02  1.364543e-02  2.653932e-02          2.672369e-02
# 6             2.965203e-02  1.403734e-02  2.965203e-02          2.915999e-02
# 7             7.845724e-02  3.681891e-02  7.845724e-02          8.051877e-02
# 8             2.613023e-02  9.865432e-03  2.613023e-02          2.633986e-02
# 9             5.420967e-03  2.109033e-03  5.420967e-03          5.981347e-03
# 10            2.464222e-02  9.268864e-03  2.464222e-02          3.554700e-02
# 11            2.654645e-02  1.097247e-02  2.654645e-02          3.720253e-02
# 12            1.487336e-02  5.265539e-03  1.487336e-02          2.252454e-02
# 13            2.872287e-02  1.152052e-02  2.872287e-02          3.865920e-02
# 14            1.669968e-02  8.606582e-03  1.669968e-02          3.672934e-02
# 15            2.516622e-02  9.322211e-03  2.516622e-02          2.401928e-02
# 16            1.011470e-02  4.357028e-03  1.011470e-02          4.421845e-02
# 17            7.181726e-02  3.052549e-02  7.181726e-02          8.581083e-02
# 18            7.487125e-03  2.575365e-03  7.487125e-03          9.250064e-03
# 19            9.369668e-03  3.467179e-03  9.369668e-03          1.394419e-02
# 20            1.526903e-04  2.452895e-04  6.313661e-04          1.555684e-04
# 21            3.650600e-04  2.002804e-04  3.650600e-04          2.959966e-04
# 22            0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 23            1.368978e-10  6.722587e-11  1.368978e-10          1.312764e-10
# 24            4.219472e-04  1.829653e-04  4.219472e-04          1.143208e-03
# 25            1.875444e-11  2.811586e-11  7.003653e-11          1.766608e-10
# 26            1.301181e-11  2.558925e-11  8.652867e-11          1.370271e-11
# 27            7.610992e-04  3.458981e-04  7.610992e-04          7.417822e-04
# 28            0.000000e+00  0.000000e+00  0.000000e+00          0.000000e+00
# 29            2.577120e-03  1.152468e-03  2.577120e-03          2.156359e-03
# 30            1.658657e-03  8.557137e-03  2.078377e-02          4.362740e-02
# 31            4.271798e-02  1.822562e-02  4.271798e-02          4.498745e-02
# 32            6.594111e-03  2.132144e-03  6.594111e-03          2.783431e-02
# 33            5.345497e-03  5.827342e-03  1.314215e-02          8.684325e-03
# 34            2.503981e-02  1.407066e-02  2.503981e-02          2.353621e-02
# 35            3.783349e-02  1.705468e-02  3.783349e-02          3.783470e-02
# 36            3.784602e-03  2.202574e-03  3.784602e-03          2.449163e-03
# 37            7.798040e-02  3.296288e-02  7.798040e-02          9.467297e-02
# 38            2.056182e-02  6.085979e-03  2.056182e-02          2.058899e-02
# 39            1.969242e-02  8.313874e-03  1.969242e-02          2.022757e-02
# 40            2.141813e-02  9.833942e-03  2.141813e-02          2.178504e-02
# 41            4.144847e-02  1.921393e-02  4.144847e-02          4.189364e-02
# 42            2.114744e-02  1.013345e-02  2.114744e-02          2.058245e-02
# 43            1.558212e-02  7.263295e-03  1.558212e-02          1.574107e-02
# 44            6.549784e-03  3.125569e-03  6.549784e-03          6.593368e-03
# 45            1.779339e-02  8.785717e-03  1.779339e-02          1.607217e-02
# 46            4.271935e-03  1.553223e-03  5.047403e-03          3.587118e-03
# 47            2.696517e-02  1.253551e-02  2.696517e-02          2.749534e-02
# 48            4.528071e-02  1.999667e-02  4.528071e-02          4.642911e-02
# 49            1.994844e-02  9.116580e-03  1.994844e-02          1.998128e-02
#
#       vx_err_avg    vx_err_max  time_fit_inner  time_step_inner  \
# 0   1.517622e-05  9.105728e-05        0.055485         0.000317
# 1   3.974223e-03  8.652390e-03        0.054725         0.000304
# 2   4.083955e-03  8.156575e-03        0.055006         0.000311
# 3   5.821087e-03  1.271425e-02        0.057498         0.000400
# 4   1.202105e-02  2.461438e-02        0.053906         0.000304
# 5   1.291401e-02  2.672369e-02        0.052922         0.000302
# 6   1.418863e-02  2.915999e-02        0.053416         0.000297
# 7   3.875844e-02  8.051877e-02        0.053546         0.000300
# 8   9.751895e-03  2.633986e-02        0.072575         0.000411
# 9   2.661757e-03  5.981347e-03        0.071157         0.000582
# 10  1.623148e-02  3.554700e-02        0.078683         0.001057
# 11  1.720194e-02  3.720253e-02        0.082079         0.001269
# 12  1.037279e-02  2.252454e-02        0.080938         0.000817
# 13  1.850965e-02  3.865920e-02        0.083909         0.000984
# 14  2.442340e-02  3.907051e-02        0.083855         0.000746
# 15  8.582412e-03  2.401928e-02        0.067805         0.000586
# 16  2.304145e-02  4.421845e-02        0.082366         0.001019
# 17  4.029030e-02  8.581083e-02        0.081879         0.000913
# 18  4.567376e-03  9.375697e-03        0.080556         0.000949
# 19  6.522389e-03  1.394419e-02        0.084968         0.001247
# 20  2.993707e-04  8.875300e-04        0.071712         0.000884
# 21  1.517847e-04  2.959966e-04        0.071740         0.000869
# 22  0.000000e+00  0.000000e+00        0.068410         0.000785
# 23  6.475866e-11  1.312764e-10        0.055095         0.000437
# 24  6.912110e-04  1.143208e-03        0.054228         0.000428
# 25  1.043802e-10  1.766608e-10        0.066939         0.000839
# 26  2.999001e-11  9.329204e-11        0.052851         0.000434
# 27  3.225801e-04  7.417822e-04        0.055900         0.000438
# 28  0.000000e+00  0.000000e+00        0.054482         0.000425
# 29  8.958848e-04  2.156359e-03        0.054021         0.000420
# 30  2.226227e-02  4.362740e-02        0.055646         0.007210
# 31  2.065317e-02  4.498745e-02        0.054112         0.007575
# 32  1.460137e-02  2.783431e-02        0.062658         0.007115
# 33  5.557385e-03  9.160699e-03        0.057059         0.006743
# 34  1.598561e-02  2.614915e-02        0.054402         0.007092
# 35  1.512959e-02  3.783470e-02        0.054311         0.007397
# 36  1.556221e-03  4.785329e-03        0.053162         0.006606
# 37  3.869914e-02  9.467297e-02        0.056795         0.007362
# 38  7.877185e-03  2.058899e-02        0.054503         0.007463
# 39  8.856393e-03  2.022757e-02        0.056439         0.007786
# 40  1.029653e-02  2.178504e-02        0.053855         0.000460
# 41  1.953524e-02  4.189364e-02        0.055758         0.000468
# 42  9.816039e-03  2.058245e-02        0.055450         0.000458
# 43  7.485997e-03  1.574107e-02        0.054065         0.000464
# 44  3.281181e-03  6.593368e-03        0.053930         0.000477
# 45  7.421295e-03  1.607217e-02        0.054298         0.000469
# 46  1.263873e-03  3.996123e-03        0.055429         0.000457
# 47  1.294592e-02  2.749534e-02        0.055680         0.000468
# 48  2.068456e-02  4.642911e-02        0.054778         0.000609
# 49  9.345863e-03  1.998128e-02        0.054821         0.000453
#
#     fit_calls_inner  step_calls_inner
# 0                 5                 5
# 1                 5                 5
# 2                 5                 5
# 3                 5                 5
# 4                 5                 5
# 5                 5                 5
# 6                 5                 5
# 7                 5                 5
# 8                 5                 5
# 9                 5                 5
# 10                5                 5
# 11                5                 5
# 12                5                 5
# 13                5                 5
# 14                5                 5
# 15                5                 5
# 16                5                 5
# 17                5                 5
# 18                5                 5
# 19                5                 5
# 20                5                 5
# 21                5                 5
# 22                5                 5
# 23                5                 5
# 24                5                 5
# 25                5                 5
# 26                5                 5
# 27                5                 5
# 28                5                 5
# 29                5                 5
# 30                5                 5
# 31                5                 5
# 32                5                 5
# 33                5                 5
# 34                5                 5
# 35                5                 5
# 36                5                 5
# 37                5                 5
# 38                5                 5
# 39                5                 5
# 40                5                 5
# 41                5                 5
# 42                5                 5
# 43                5                 5
# 44                5                 5
# 45                5                 5
# 46                5                 5
# 47                5                 5
# 48                5                 5
# 49                5                 5
#
# [50 rows x 22 columns]
# === Aggregate by dynamics (final repeat only) ===
# dynamics                             coca  friedkinjohnsen  hegselmannkrause  \
# repeat                 count    10.000000     1.000000e+01         10.000000
#                        mean     99.000000     9.900000e+01         99.000000
#                        std       0.000000     0.000000e+00          0.000000
#                        min      99.000000     9.900000e+01         99.000000
#                        25%      99.000000     9.900000e+01         99.000000
#                        50%      99.000000     9.900000e+01         99.000000
#                        75%      99.000000     9.900000e+01         99.000000
#                        max      99.000000     9.900000e+01         99.000000
# train_pairs_total      count    10.000000     1.000000e+01         10.000000
#                        mean   2000.000000     2.000000e+03       2000.000000
#                        std       0.000000     0.000000e+00          0.000000
#                        min    2000.000000     2.000000e+03       2000.000000
#                        25%    2000.000000     2.000000e+03       2000.000000
#                        50%    2000.000000     2.000000e+03       2000.000000
#                        75%    2000.000000     2.000000e+03       2000.000000
#                        max    2000.000000     2.000000e+03       2000.000000
# v_L1_final             count    10.000000     1.000000e+01         10.000000
#                        mean      0.504561     1.225015e-01          0.594449
#                        std       0.113706     3.636225e-02          0.170986
#                        min       0.369051     7.978533e-02          0.386392
#                        25%       0.442180     1.061758e-01          0.509776
#                        50%       0.481565     1.149162e-01          0.546768
#                        75%       0.495852     1.303930e-01          0.684509
#                        max       0.713383     2.094716e-01          0.938130
# A_MAE_final            count    10.000000     1.000000e+01         10.000000
#                        mean      0.079326     6.349061e-03          0.099886
#                        std       0.012696     8.743016e-04          0.006882
#                        min       0.053999     5.280523e-03          0.090579
#                        25%       0.073660     5.684717e-03          0.095303
#                        50%       0.083032     6.081575e-03          0.099965
#                        75%       0.088406     7.217411e-03          0.101310
#                        max       0.091869     7.469402e-03          0.112079
# mean_gap_to_oracle_end count    10.000000     1.000000e+01         10.000000
#                        mean      0.023544     4.277917e-04          0.024121
#                        std       0.018652     7.975925e-04          0.023678
#                        min       0.007487     0.000000e+00          0.001659
#                        25%       0.011304     1.444747e-11          0.005658
#                        50%       0.020671     7.634523e-05          0.020127
#                        75%       0.026201     4.077254e-04          0.034635
#                        max       0.071817     2.577120e-03          0.077980
# vx_gap_to_oracle_end   count    10.000000     1.000000e+01         10.000000
#                        mean      0.034791     4.492914e-04          0.032444
#                        std       0.021267     7.149387e-04          0.025903
#                        min       0.009250     0.000000e+00          0.002449
#                        25%       0.022898     4.309614e-11          0.020318
#                        50%       0.036138     7.778430e-05          0.025685
#                        75%       0.038295     6.303358e-04          0.042179
#                        max       0.085811     2.156359e-03          0.094673
# time_fit_inner         count    10.000000     1.000000e+01         10.000000
#                        mean      0.080704     6.053766e-02          0.055909
#                        std       0.004887     8.044810e-03          0.002700
#                        min       0.067805     5.285060e-02          0.053162
#                        25%       0.080651     5.429130e-02          0.054334
#                        50%       0.081979     5.549755e-02          0.055075
#                        75%       0.083483     6.804235e-02          0.056706
#                        max       0.084968     7.173960e-02          0.062658
#
# dynamics                        laplacian  nonlinearinfluence
# repeat                 count    10.000000           10.000000
#                        mean     99.000000           99.000000
#                        std       0.000000            0.000000
#                        min      99.000000           99.000000
#                        25%      99.000000           99.000000
#                        50%      99.000000           99.000000
#                        75%      99.000000           99.000000
#                        max      99.000000           99.000000
# train_pairs_total      count    10.000000           10.000000
#                        mean   2000.000000         2000.000000
#                        std       0.000000            0.000000
#                        min    2000.000000         2000.000000
#                        25%    2000.000000         2000.000000
#                        50%    2000.000000         2000.000000
#                        75%    2000.000000         2000.000000
#                        max    2000.000000         2000.000000
# v_L1_final             count    10.000000           10.000000
#                        mean      0.416383            0.369933
#                        std       0.099582            0.092035
#                        min       0.259944            0.203741
#                        25%       0.356245            0.310562
#                        50%       0.425086            0.387631
#                        75%       0.446374            0.418713
#                        max       0.588677            0.497134
# A_MAE_final            count    10.000000           10.000000
#                        mean      0.051713            0.046992
#                        std       0.011460            0.016972
#                        min       0.037407            0.020037
#                        25%       0.041785            0.034735
#                        50%       0.051169            0.048556
#                        75%       0.057411            0.052448
#                        max       0.069693            0.073880
# mean_gap_to_oracle_end count    10.000000           10.000000
#                        mean      0.021662            0.022041
#                        std       0.022381            0.013174
#                        min       0.000474            0.004272
#                        25%       0.007079            0.016135
#                        50%       0.017491            0.020548
#                        75%       0.026437            0.025578
#                        max       0.078457            0.045281
# vx_gap_to_oracle_end   count    10.000000           10.000000
#                        mean      0.022295            0.022016
#                        std       0.022890            0.013661
#                        min       0.000091            0.003587
#                        25%       0.008281            0.015824
#                        50%       0.018664            0.020282
#                        75%       0.026628            0.026068
#                        max       0.080519            0.046429
# time_fit_inner         count    10.000000           10.000000
#                        mean      0.058024            0.054806
#                        std       0.007418            0.000742
#                        min       0.052922            0.053855
#                        25%       0.053636            0.054123
#                        50%       0.054866            0.054800
#                        75%       0.056994            0.055445
#                        max       0.072575            0.055758

# %%
import numpy as np
import matplotlib.pyplot as plt

from opinion_dynamics.experiments.plots import (
    plot_impulse_node_trajectories,
    show_matrix_with_cell_grid,
    concat_intermediate,
)
from opinion_dynamics.experiments.metrics import graph_sanity
from opinion_dynamics.experiments.rollouts import (
    rollout_with_v_intermediate,
    make_env_with_dynamics,
)
from opinion_dynamics.experiments.online_repeated import run_repeated_online_id_on_env
from opinion_dynamics.utils.env_setup import EnvironmentFactory


# =========================================================
# Settings
# =========================================================
SEED_TO_PLOT = 10
NUM_REPEATS = 100
REPEAT_TO_PLOT = NUM_REPEATS - 1   # final accumulated repeat

# Use the same list as in the summary cell
DYNAMICS_LIST = [
    "laplacian",
    "coca",
    "friedkinjohnsen",
    "hegselmannkrause",
    "nonlinearinfluence",
    # "repulsion",
]

# Keep the same fit map as in the summary cell
FIT_BY_DYNAMICS = {
    "laplacian": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=1e-2, fit_batch_size=256, fit_check_every=200),
    "coca": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=512, fit_check_every=200),
    "friedkinjohnsen": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    "hegselmannkrause": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    "nonlinearinfluence": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=2e-2, fit_batch_size=256, fit_check_every=200),
    # "repulsion": dict(fit_max_steps=FIT_MAX_STEPS, fit_mae_stop=3e-2, fit_batch_size=256, fit_check_every=200),
}

env_factory = EnvironmentFactory()


def make_eval_env(dynamics_name):
    return make_env_with_dynamics(
        env_factory,
        seed=SEED_TO_PLOT,
        dynamics_model=dynamics_name,
    )


for DYNAMICS in DYNAMICS_LIST:
    print("\n" + "=" * 80)
    print(f"=== DYNAMICS: {DYNAMICS} | SEED {SEED_TO_PLOT} ===")
    print("=" * 80)

    FIT_KW = FIT_BY_DYNAMICS[DYNAMICS]

    # =========================================================
    # 1) Train with accumulated experience across many repeats 
    #    on the same graph topology
    # =========================================================
    env_template = make_eval_env(DYNAMICS)

    out = run_repeated_online_id_on_env(
        env_template,
        num_repeats=NUM_REPEATS,
        B_campaign=B_campaign,
        num_campaigns_total=num_campaigns_total,
        lr=1e-3,
        l2_lambda=0.0,
        device="cpu",
        update_A_each_campaign=True,
        suppress_fit_logs=True,
        **FIT_KW,
    )

    metrics = out["rows"][REPEAT_TO_PLOT]
    art = out["artifacts"][REPEAT_TO_PLOT]

    print(f"=== REPEAT {REPEAT_TO_PLOT + 1}/{NUM_REPEATS} ===")
    print(f"train_pairs_total: {metrics['train_pairs_total']}")
    print("=== METRICS ===")
    for k, v in metrics.items():
        print(f"{k}: {v}")

    # =========================================================
    # 2) Pull ground-truth + learned-final
    # =========================================================
    A_true = np.asarray(art["A_true"], dtype=float)
    v_true = np.asarray(art["v_true"], dtype=float)

    A_hat_final = np.asarray(art["A_hat_final"], dtype=float)
    v_hat_final = np.asarray(art["v_hat_final"], dtype=float)

    states_learn_actual = np.asarray(art["states"], dtype=float)
    N = states_learn_actual.shape[1]
    K_total = states_learn_actual.shape[0] - 1

    # =========================================================
    # 3) Build a reproducible evaluation x0 from the ORIGINAL seed
    # =========================================================
    env_x0 = make_eval_env(DYNAMICS)
    x0_plot, _ = env_x0.reset()
    x0_plot = np.asarray(x0_plot, dtype=float)
    dt = float(getattr(env_x0, "t_s", 1.0))

    # =========================================================
    # 4) GRAPH SANITY (true vs learned-final)
    # =========================================================
    print("\n=== GRAPH SANITY (TRUE) ===")
    for k, v in graph_sanity(A_true).items():
        print(f"{k}: {v}")

    print("\n=== GRAPH SANITY (LEARNED FINAL) ===")
    for k, v in graph_sanity(A_hat_final).items():
        print(f"{k}: {v}")

    show_matrix_with_cell_grid(
        A_true,
        title=f"True A ({DYNAMICS}, seed={SEED_TO_PLOT})",
        grid_alpha=0.25,
        grid_lw=0.6,
    )
    show_matrix_with_cell_grid(
        A_hat_final,
        title=f"Learned A_hat final ({DYNAMICS}, seed={SEED_TO_PLOT}, final repeat)",
        grid_alpha=0.25,
        grid_lw=0.6,
    )

    # =========================================================
    # 5) Evaluate all comparison curves on the SAME common x0
    # =========================================================
    le_out = rollout_with_v_intermediate(
        make_eval_env(DYNAMICS),
        x0_plot,
        K_total,
        B_campaign,
        v_hat_final,
        zero_first_campaign=True,
    )

    or_out = rollout_with_v_intermediate(
        make_eval_env(DYNAMICS),
        x0_plot,
        K_total,
        B_campaign,
        v_true,
        zero_first_campaign=True,
    )

    nc_out = rollout_with_v_intermediate(
        make_eval_env(DYNAMICS),
        x0_plot,
        K_total,
        B_campaign,
        None,
        zero_first_campaign=True,
    )

    order = np.argsort(v_true)
    ranks = np.empty_like(order, dtype=float)
    ranks[order] = np.arange(1, len(v_true) + 1)
    v_anti = 1.0 / ranks
    v_anti = v_anti / v_anti.sum()

    anti_out = rollout_with_v_intermediate(
        make_eval_env(DYNAMICS),
        x0_plot,
        K_total,
        B_campaign,
        v_anti,
        zero_first_campaign=True,
    )

    # =========================================================
    # 6) Fine-grained trajectories
    # =========================================================
    X_le, T_le = concat_intermediate(
        le_out["intermediate_states_list"],
        le_out["intermediate_times_list"],
        dt=dt,
    )
    X_or, T_or = concat_intermediate(
        or_out["intermediate_states_list"],
        or_out["intermediate_times_list"],
        dt=dt,
    )

    plot_impulse_node_trajectories(
        X_or,
        T_or,
        title=f"Node trajectories (fine-grained) — ORACLE true v ({DYNAMICS}, seed={SEED_TO_PLOT})",
    )
    plot_impulse_node_trajectories(
        X_le,
        T_le,
        title=f"Node trajectories (fine-grained) — LEARNED final controller ({DYNAMICS}, seed={SEED_TO_PLOT})",
    )

    # =========================================================
    # 7) Centrality comparison (NO sorting)
    # =========================================================
    print("\n=== CENTRALITY COMPARISON (by node index) ===")
    print("L1(v_hat_final - v_true):", float(np.sum(np.abs(v_hat_final - v_true))))

    idx = np.arange(N)
    diff = v_hat_final - v_true

    plt.figure(figsize=(10, 4))
    plt.plot(idx, v_true, marker="o", label="v_true")
    plt.plot(idx, v_hat_final, marker="o", label="v_hat_final")
    plt.xlabel("node index i")
    plt.ylabel("centrality value")
    plt.title(f"Centrality comparison (true vs learned) — {DYNAMICS}, seed={SEED_TO_PLOT}")
    plt.xticks(idx)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 3))
    plt.axhline(0.0, linewidth=1)
    plt.plot(idx, diff, marker="o")
    plt.xlabel("node index i")
    plt.ylabel("v_hat - v_true")
    plt.title(f"Centrality error per node — {DYNAMICS}, seed={SEED_TO_PLOT}")
    plt.xticks(idx)
    plt.grid(True, alpha=0.3)
    plt.show()

    # =========================================================
    # 8) Mean opinion plot at campaign boundaries
    # =========================================================
    states_learn = np.asarray(le_out["states"], dtype=float)
    states_oracle = np.asarray(or_out["states"], dtype=float)
    states_noc = np.asarray(nc_out["states"], dtype=float)
    states_anti = np.asarray(anti_out["states"], dtype=float)

    mean_learn = states_learn.mean(axis=1)
    mean_or = states_oracle.mean(axis=1)
    mean_nc = states_noc.mean(axis=1)
    mean_anti = states_anti.mean(axis=1)

    plt.figure(figsize=(8, 3))
    plt.plot(mean_learn, marker="o", label="learned final controller")
    plt.plot(mean_or, marker="o", label="oracle (true v)")
    plt.plot(mean_anti, marker="o", label="wrong places (least-central)")
    plt.plot(mean_nc, marker="o", label="no control")
    plt.xlabel("Campaign boundary k")
    plt.ylabel("mean opinion")
    plt.title(f"Trajectory: mean opinion — {DYNAMICS}, seed={SEED_TO_PLOT} (common x0)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.ylim(0, 1)
    plt.show()

    print("\n=== CAMPAIGN-0 OVERLAP CHECK ===")
    print(
        "learned states[1] vs oracle states[1] L_inf:",
        float(np.max(np.abs(states_learn[1] - states_oracle[1]))),
    )
    print(
        "learned states[1] vs nocontrol states[1] L_inf:",
        float(np.max(np.abs(states_learn[1] - states_noc[1]))),
    )
# Out:
# ================================================================================
# === DYNAMICS: laplacian | SEED 10 ===
# ================================================================================
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === REPEAT 100/100 ===
# train_pairs_total: 2000
# === METRICS ===
# seed: 10
# repeat: 99
# repeat_seed: 1000010
# dynamics: laplacian
# N: 15
# train_pairs_total: 2000
# v_L1_final: 0.28873958136723693
# A_Fro_final: 1.8701156222995223
# A_MAE_final: 0.07019950788261162
# mean_oracle_end: 0.711676300994918
# mean_learn_end: 0.7025274293797944
# mean_noc_end: 0.5273579201118945
# mean_gap_to_oracle_end: 0.009148871615123566
# mean_err_avg: 0.004725772647786582
# mean_err_max: 0.009148871615123566
# vx_gap_to_oracle_end: 0.008737351268831683
# vx_err_avg: 0.0042613520328049215
# vx_err_max: 0.008737351268831683
# time_fit_inner: 0.05540010007098317
# time_step_inner: 0.0003078998997807503
# fit_calls_inner: 5
# step_calls_inner: 5
#
# === GRAPH SANITY (TRUE) ===
# diag_max: 0.0
# row_sum_min: 0.9999999999999998
# row_sum_mean: 1.0
# row_sum_max: 1.0
# asym: 1.0017820031950908
# edges: 39
# sink_sizes: [15]
# has_singleton_sink: False
#
# === GRAPH SANITY (LEARNED FINAL) ===
# diag_max: 0.0
# row_sum_min: 0.9999999050050974
# row_sum_mean: 0.9999999897244076
# row_sum_max: 1.0000000894069672
# asym: 0.8009268766343023
# edges: 210
# sink_sizes: [15]
# has_singleton_sink: False
# === CENTRALITY COMPARISON (by node index) ===
# L1(v_hat_final - v_true): 0.28873958136723693
# === CAMPAIGN-0 OVERLAP CHECK ===
# learned states[1] vs oracle states[1] L_inf: 0.0
# learned states[1] vs nocontrol states[1] L_inf: 0.0
#
# ================================================================================
# === DYNAMICS: coca | SEED 10 ===
# ================================================================================
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === REPEAT 100/100 ===
# train_pairs_total: 2000
# === METRICS ===
# seed: 10
# repeat: 99
# repeat_seed: 1000010
# dynamics: coca
# N: 15
# train_pairs_total: 2000
# v_L1_final: 0.28169498424948364
# A_Fro_final: 1.899429063852264
# A_MAE_final: 0.06040047758173015
# mean_oracle_end: 0.6940416482202632
# mean_learn_end: 0.7000708173718393
# mean_noc_end: 0.5412247193640938
# mean_gap_to_oracle_end: 0.006029169151576141
# mean_err_avg: 0.005727135457298638
# mean_err_max: 0.010438691440887493
# vx_gap_to_oracle_end: 0.002036258629727117
# vx_err_avg: 0.0006803958660225873
# vx_err_max: 0.002036258629727117
# time_fit_inner: 0.06471740000415593
# time_step_inner: 0.0005495001096278429
# fit_calls_inner: 5
# step_calls_inner: 5
#
# === GRAPH SANITY (TRUE) ===
# diag_max: 0.0
# row_sum_min: 0.9999999999999998
# row_sum_mean: 1.0
# row_sum_max: 1.0
# asym: 1.0017820031950908
# edges: 39
# sink_sizes: [15]
# has_singleton_sink: False
#
# === GRAPH SANITY (LEARNED FINAL) ===
# diag_max: 0.0
# row_sum_min: 0.9999998700805008
# row_sum_mean: 0.9999999911660173
# row_sum_max: 1.0000001291627996
# asym: 0.7568861777154583
# edges: 210
# sink_sizes: [15]
# has_singleton_sink: False
# === CENTRALITY COMPARISON (by node index) ===
# L1(v_hat_final - v_true): 0.28169498424948364
# === CAMPAIGN-0 OVERLAP CHECK ===
# learned states[1] vs oracle states[1] L_inf: 0.0
# learned states[1] vs nocontrol states[1] L_inf: 0.0
#
# ================================================================================
# === DYNAMICS: friedkinjohnsen | SEED 10 ===
# ================================================================================
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === REPEAT 100/100 ===
# train_pairs_total: 2000
# === METRICS ===
# seed: 10
# repeat: 99
# repeat_seed: 1000010
# dynamics: friedkinjohnsen
# N: 15
# train_pairs_total: 2000
# v_L1_final: 0.07585789923195797
# A_Fro_final: 0.22240420974480088
# A_MAE_final: 0.00564585025649853
# mean_oracle_end: 0.6006539052607374
# mean_learn_end: 0.6006539052607374
# mean_noc_end: 0.5222255358544711
# mean_gap_to_oracle_end: 0.0
# mean_err_avg: 0.0
# mean_err_max: 0.0
# vx_gap_to_oracle_end: 0.0
# vx_err_avg: 0.0
# vx_err_max: 0.0
# time_fit_inner: 0.053896899917162955
# time_step_inner: 0.0004211999475955963
# fit_calls_inner: 5
# step_calls_inner: 5
#
# === GRAPH SANITY (TRUE) ===
# diag_max: 0.0
# row_sum_min: 0.9999999999999998
# row_sum_mean: 1.0
# row_sum_max: 1.0
# asym: 1.0017820031950908
# edges: 39
# sink_sizes: [15]
# has_singleton_sink: False
#
# === GRAPH SANITY (LEARNED FINAL) ===
# diag_max: 0.0
# row_sum_min: 0.9999999332962943
# row_sum_mean: 0.9999999999600744
# row_sum_max: 1.0000002027911705
# asym: 0.9176727502830707
# edges: 210
# sink_sizes: [15]
# has_singleton_sink: False
# === CENTRALITY COMPARISON (by node index) ===
# L1(v_hat_final - v_true): 0.07585789923195797
# === CAMPAIGN-0 OVERLAP CHECK ===
# learned states[1] vs oracle states[1] L_inf: 0.0
# learned states[1] vs nocontrol states[1] L_inf: 0.0
#
# ================================================================================
# === DYNAMICS: hegselmannkrause | SEED 10 ===
# ================================================================================
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === REPEAT 100/100 ===
# train_pairs_total: 2000
# === METRICS ===
# seed: 10
# repeat: 99
# repeat_seed: 1000010
# dynamics: hegselmannkrause
# N: 15
# train_pairs_total: 2000
# v_L1_final: 0.4112586123917959
# A_Fro_final: 3.059689299096414
# A_MAE_final: 0.10730435871410124
# mean_oracle_end: 0.6917261329020626
# mean_learn_end: 0.6779188916359344
# mean_noc_end: 0.5077709558139776
# mean_gap_to_oracle_end: 0.0138072412661282
# mean_err_avg: 0.008127456212247567
# mean_err_max: 0.01599034848241998
# vx_gap_to_oracle_end: 0.018420087897994653
# vx_err_avg: 0.009296114552276857
# vx_err_max: 0.018420087897994653
# time_fit_inner: 0.05394359992351383
# time_step_inner: 0.007272600079886615
# fit_calls_inner: 5
# step_calls_inner: 5
#
# === GRAPH SANITY (TRUE) ===
# diag_max: 0.0
# row_sum_min: 0.9999999999999998
# row_sum_mean: 1.0
# row_sum_max: 1.0
# asym: 1.0017820031950908
# edges: 39
# sink_sizes: [15]
# has_singleton_sink: False
#
# === GRAPH SANITY (LEARNED FINAL) ===
# diag_max: 0.0
# row_sum_min: 0.9999998843995854
# row_sum_mean: 1.0000000150311583
# row_sum_max: 1.000000175088644
# asym: 0.8329405730431508
# edges: 210
# sink_sizes: [15]
# has_singleton_sink: False
# === CENTRALITY COMPARISON (by node index) ===
# L1(v_hat_final - v_true): 0.4112586123917959
# === CAMPAIGN-0 OVERLAP CHECK ===
# learned states[1] vs oracle states[1] L_inf: 0.0
# learned states[1] vs nocontrol states[1] L_inf: 0.0
#
# ================================================================================
# === DYNAMICS: nonlinearinfluence | SEED 10 ===
# ================================================================================
# [identifier-init] class=GraphIdentifierEnvFreeProp module=opinion_dynamics.identify_freeprop file=d:\Work\repos\RL\unknown_graph_networks\opinion_dynamics\identify_freeprop.py:8
# === REPEAT 100/100 ===
# train_pairs_total: 2000
# === METRICS ===
# seed: 10
# repeat: 99
# repeat_seed: 1000010
# dynamics: nonlinearinfluence
# N: 15
# train_pairs_total: 2000
# v_L1_final: 0.3964742478102084
# A_Fro_final: 1.5626787889539477
# A_MAE_final: 0.05635568289835223
# mean_oracle_end: 0.7199091157194545
# mean_learn_end: 0.6828910435457461
# mean_noc_end: 0.5324715196775764
# mean_gap_to_oracle_end: 0.03701807217370834
# mean_err_avg: 0.017597594601177713
# mean_err_max: 0.03701807217370834
# vx_gap_to_oracle_end: 0.03584235616812925
# vx_err_avg: 0.016992734390187687
# vx_err_max: 0.03584235616812925
# time_fit_inner: 0.05579750007018447
# time_step_inner: 0.0004635999212041497
# fit_calls_inner: 5
# step_calls_inner: 5
#
# === GRAPH SANITY (TRUE) ===
# diag_max: 0.0
# row_sum_min: 0.9999999999999998
# row_sum_mean: 1.0
# row_sum_max: 1.0
# asym: 1.0017820031950908
# edges: 39
# sink_sizes: [15]
# has_singleton_sink: False
#
# === GRAPH SANITY (LEARNED FINAL) ===
# diag_max: 0.0
# row_sum_min: 0.9999999227002263
# row_sum_mean: 1.0000000045634807
# row_sum_max: 1.0000000800937414
# asym: 0.8359786624966419
# edges: 210
# sink_sizes: [15]
# has_singleton_sink: False
# === CENTRALITY COMPARISON (by node index) ===
# L1(v_hat_final - v_true): 0.3964742478102084
# === CAMPAIGN-0 OVERLAP CHECK ===
# learned states[1] vs oracle states[1] L_inf: 0.0
# learned states[1] vs nocontrol states[1] L_inf: 0.0
